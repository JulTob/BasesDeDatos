# %% [markdown]
# <a href="https://colab.research.google.com/github/JulTob/BasesDeDatos/blob/main/Practicas/P0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fundamentos de Bases de Datos
# **2º Grado en Ciencia de Datos e Inteligencia Artificial**
# *Curso 2026-2027*
#
# ## FBD 25/26 - Práctica 1
#
# ### Objetivo
# El objetivo de esta actividad es experimentar las consecuencias que puede tener sobre un programa la modificación de la estructura o de las características de los datos que utiliza.
#
# Para ello se desarrollará una pequeña aplicación en Python y, posteriormente, se modificarán algunos de sus requisitos. Durante la realización de la actividad deberás registrar el tiempo empleado en el desarrollo y modificación del programa, así como las pruebas realizadas para comprobar su correcto funcionamiento.

# %% [markdown]
# ### Parte 1. Desarrollo de la aplicación
#
# Desarrolla en Python un programa sencillo que solicite por teclado los siguientes datos correspondientes a un ticket de venta:
# * Fecha de venta.
# * Número de ticket.
# * Artículo.
# * Cantidad.
# * Precio unitario, expresado en pesetas.
#
# El programa deberá calcular el importe total correspondiente al ticket:
# $$\text{Importe Total} = \text{Cantidad} \times \text{Precio Unitario}$$
#
# Finalmente, deberá mostrar los datos introducidos y el importe total calculado.
#
# #### Almacenamiento de los datos
# Además de mostrar los datos introducidos, el programa deberá almacenar cada ticket en un fichero denominado `tickets.csv`. Cada nuevo ticket deberá añadirse al fichero conservando la información almacenada anteriormente.
#
# El número de ticket deberá ser único. Antes de almacenar los datos, el programa deberá comprobar la información previamente guardada en el fichero. Si ya existe un ticket con el mismo número, el programa deberá informar de esta circunstancia y no permitirá almacenarlo.
#
# Para realizar esta parte de la actividad puede consultarse la documentación oficial de Python relativa al módulo `csv`, que proporciona funciones para leer y escribir datos en ficheros CSV:
# * [Documentación oficial de Python: módulo csv](https://docs.python.org/es/3/library/csv.html)
#
# #### Validación y pruebas
# El programa deberá comprobar que:
# * La fecha introducida sea válida.
# * El número de ticket sea un número entero positivo.
# * La cantidad sea un número entero positivo mayor que 0.
# * El precio unitario sea un valor numérico positivo entero mayor que 0.
#
# Antes de comenzar, anota la hora de inicio. Una vez terminado el programa:
# 1. Anota el tiempo empleado en su desarrollo.
# 2. Realiza las pruebas que consideres necesarias para verificar su correcto funcionamiento.
# 3. Anota las pruebas realizadas y sus resultados.
#
# Entre las pruebas de funcionamiento deberá incluirse, al menos, el intento de almacenar dos tickets con el mismo número, comprobando que el segundo no se almacena y documentando el comportamiento observado.

# %%
from datetime import datetime
verify = datetime.strptime

def GetDate():
    try:
        date_txt = input("¿Fecha (DD/MM/AAAA)? ")
        formato = "%d/%m/%Y"
        date = verify(date_txt, formato)
        return date
    except Exception as e:
        raise ValueError("La fecha introducida no tiene un formato válido (DD/MM/AAAA) o no es una fecha real.")


def GetTicketNumber():
    try:
        n_ticket = int(input("¿Número de Ticket? "))
        assert n_ticket > 0, "El número de ticket debe ser un número entero positivo"
        return n_ticket
    except Exception as e:
        raise ValueError(f"Ocurrió un error en la lectura del número de ticket: {e}")


def GetArticulo():
    try:
        product = input("¿Artículo? ")
        return product
    except Exception as e:
        raise ValueError(f"Ocurrió un error en la lectura del artículo: {e}")


def GetQuantity(product):
    try:
        quantity = int(input(f"¿Cantidad de {product}? "))
        assert quantity > 0, "La cantidad debe ser un entero mayor de 0"
        return quantity
    except Exception as e:
        raise ValueError(f"Ocurrió un error en la lectura de la cantidad: {e}")


def GetPrice():
    try:
        price = int(input("¿Precio unitario? "))
        assert price > 0, "El precio debe ser un entero mayor de 0"
        return price
    except Exception as e:
        raise ValueError(f"Ocurrió un error en la lectura del precio: {e}")

# %%
def DummyTicket():
    """
    Dummy ticket para testeos.
    """
    ticket = {}
    ticket['date'] = "12/12/2012"
    ticket['n_ticket'] = 0
    ticket['product'] = "Cosa"
    ticket['quantity'] = 1
    ticket['price'] = 10

    ticket['total'] = ticket['quantity'] * ticket['price']

    return ticket

# %%
def Solicitud():
    try:
        print("Solicitud de ticket")
        print("-------------------")
        ticket = {}

        ticket['date'] = GetDate()
        ticket['n_ticket'] = GetTicketNumber()
        ticket['product'] = GetArticulo()
        ticket['quantity'] = GetQuantity(ticket['product'])
        ticket['price'] = GetPrice()

        ticket['total'] = ticket['quantity'] * ticket['price']
        return ticket
    except Exception as e:
        raise ValueError(f"Ocurrió un error en la solicitud de ticket: {e}")

def Ticket_Print(ticket):
    print("Ticket")
    print("-------")
    print(f"Fecha: {ticket['date']}")
    print(f"Ticket: {ticket['n_ticket']}")
    print(f"Artículo: {ticket['product']}")
    print(f"Cantidad: {ticket['quantity']}")
    print(f"Precio: {ticket['price']}")
    print(f"Total: {ticket['total']}")

# %%
ticket = DummyTicket()
#ticket = Solicitud()
#-- Para testeo.
Ticket_Print(ticket)
# Out:
# Ticket
# -------
# Fecha: 12/12/2012
# Ticket: 0
# Artículo: Cosa
# Cantidad: 1
# Precio: 10
# Total: 10

# %%
import csv
import os

tickets_file = "tickets.csv"

def ValidateTicket(ticket, tickets_file):
    ticket_n = ticket['n_ticket']
    with open(tickets_file, mode='r', encoding='utf-8') as file:
        reader = csv.reader(file)
        for row in reader:
            if ticket_n == int(row[1]):
                return False
    return True

# %% [markdown]
# ### Parte 2. Primer cambio de requisitos: cambio de mano de obra / moneda
#
# La empresa comunica que, a partir de este momento, los precios de los artículos se expresarán en euros en lugar de pesetas, ahora admitiendo un máximo de dos decimales.
#
# Realiza las modificaciones necesarias en el programa desarrollado en la Parte 1. Una vez terminadas las modificaciones:
# 4. Anota el tiempo empleado.
# 5. Identifica las partes del programa que has tenido que modificar.
# 6. Realiza nuevamente las pruebas necesarias.
# 7. Anota las pruebas realizadas y sus resultados.

# %% [markdown]
# ### Parte 3. Segundo cambio de requisitos: incorporación de un nuevo dato
#
# La empresa decide incorporar a cada ticket un nuevo dato denominado **Descuento**. Dicho descuento:
# * Se expresará mediante un porcentaje.
# * Deberá estar comprendido entre 0 y 100.
#
# El importe total del ticket deberá calcularse ahora teniendo en cuenta dicho descuento, redondeando el resultado a dos decimales:
# $$\text{Importe Total} = \text{Cantidad} \times \text{Precio Unitario} \times \left(1 - \frac{\text{Descuento}}{100}\right)$$
#
# Modifica nuevamente el programa para satisfacer los nuevos requisitos. Una vez realizada la modificación:
# 8. Anota el tiempo empleado.
# 9. Identifica qué partes del programa anterior has tenido que modificar.
# 10. Realiza las pruebas necesarias para verificar el correcto funcionamiento de la nueva versión.
# 11. Anota las pruebas realizadas y sus resultados.
# 12. Indica si alguna de las pruebas de las versiones anteriores ha tenido que ser modificada.
#
# #### Registro del trabajo
#
# | Tarea | Tiempo empleado | Cambios realizados | Pruebas realizadas |
# | :--- | :--- | :--- | :--- |
# | Desarrollo de la versión inicial | | | |
# | Cambio de pesetas a euros | | | |
# | Incorporación del descuento | | | |

# %% [markdown]
# ### Parte 4. Análisis de los resultados
#
# a) ¿Dónde se encuentra definida en el programa la naturaleza de cada dato utilizado (fecha, número de ticket, cantidad, precio, etc.)?
#
# b) ¿Qué partes del programa se han visto afectadas por el cambio de pesetas a euros?
#
# c) ¿Qué partes del programa se han visto afectadas al incorporar el nuevo dato Descuento?
#
# d) Si los mismos datos fueran utilizados por cinco programas diferentes, ¿qué consecuencias tendrían los cambios anteriores sobre dichos programas?
#
# e) ¿Qué problemas podrían producirse si diferentes programas almacenaran y gestionaran independientemente sus propias copias de los mismos datos?
#
# f) ¿Qué ocurriría si fuera necesario realizar nuevos cambios en la estructura de los datos en un futuro?
#
# g) A la vista de la experiencia realizada, ¿qué ventajas consideras que podría tener separar la definición y gestión de los datos de los programas que los utilizan?
#
# h) ¿Qué ha sido necesario hacer en el programa para garantizar que no puedan almacenarse dos tickets con el mismo número? ¿Dónde queda definida y comprobada esta restricción?
#
# ### Reflexión final
# ¿Sería posible definir los datos una sola vez y permitir que diferentes programas trabajasen con ellos sin tener que incorporar su definición y gestión en cada programa?
